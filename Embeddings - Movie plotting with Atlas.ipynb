# %% [markdown]
# ## Requirements

# %%
# !pip install pandas numpy tenacity

# %% [markdown]
# ## Init OpenAI

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:1234/v1",
    api_key="lm-studio",
)

# %% [markdown]
# ## Load csv data

# %%
import pandas as pd

dataset_path = "./movie_plots.csv"
df = pd.read_csv(dataset_path)

# %% [markdown]
# ## Filter movie for 1000 sample

# %%
movie = df[df["Origin/Ethnicity"] == "American"].sort_values("Release Year", ascending=False).head(1000)

# %% [markdown]
# ## Tenacity used for retry if there is an error because of rate limit

# %%
movie
# Out:
#        Release Year                                   Title Origin/Ethnicity  \
# 17271          2017                                    2:22         American
# 17375          2017                            Molly's Game         American
# 17343          2017                               Lady Bird         American
# 17325          2017  Professor Marston and the Wonder Women         American
# 17352          2017                           Mr. Roosevelt         American
# ...             ...                                     ...              ...
# 16203          2012                              Black Rock         American
# 16204          2012                              Border Run         American
# 16205          2012     Bourne Legacy, TheThe Bourne Legacy         American
# 16190          2012             Beasts of the Southern Wild         American
# 16207          2012                                 Branded         American
#
#                                     Director  \
# 17271                            Paul Currie
# 17375                           Aaron Sorkin
# 17343                           Greta Gerwig
# 17325                        Angela Robinson
# 17352                             Noël Wells
# ...                                      ...
# 16203                          Katie Aselton
# 16204                    Gabriela Tagliavini
# 16205                            Tony Gilroy
# 16190                           Benh Zeitlin
# 16207  Jamie Bradshaw and Aleksandr Dulerayn
#
#                                                     Cast  \
# 17271  Paul Currie (director); Nathan Parker, Todd St...
# 17375  Aaron Sorkin (director/screenplay); Jessica Ch...
# 17343  Greta Gerwig (director/screenplay); Saoirse Ro...
# 17325  Angela Robinson (director/screenplay); Luke Ev...
# 17352  Noël Wells (director/screenplay); Noël Wells, ...
# ...                                                  ...
# 16203  Katie Aselton, Lake Bell, Kate Bosworth, Will ...
# 16204  Sharon Stone, Billy Zane, Manolo Cardona, Rose...
# 16205  Jeremy Renner, Rachel Weisz, Edward Norton, Jo...
# 16190  Quvenzhané Wallis, Dwight Henry, Jonshel Alexa...
# 16207  Ed Stoppard, Leelee Sobieski, Jeffrey Tambor, ...
#
#                          Genre  \
# 17271          drama, thriller
# 17375  biography, crime, drama
# 17343             comedy-drama
# 17325         biography, drama
# 17352                   comedy
# ...                        ...
# 16203                   horror
# 16204                    drama
# 16205         action, spy film
# 16190           drama, fantasy
# 16207          science fiction
#
#                                                Wiki Page  \
# 17271     https://en.wikipedia.org/wiki/2:22_(2017_film)
# 17375       https://en.wikipedia.org/wiki/Molly%27s_Game
# 17343     https://en.wikipedia.org/wiki/Lady_Bird_(film)
# 17325  https://en.wikipedia.org/wiki/Professor_Marsto...
# 17352        https://en.wikipedia.org/wiki/Mr._Roosevelt
# ...                                                  ...
# 16203  https://en.wikipedia.org/wiki/Black_Rock_(2012...
# 16204           https://en.wikipedia.org/wiki/Border_Run
# 16205  https://en.wikipedia.org/wiki/The_Bourne_Legac...
# 16190  https://en.wikipedia.org/wiki/Beasts_of_the_So...
# 16207  https://en.wikipedia.org/wiki/Branded_(2012_film)
#
#                                                     Plot
# 17271  The movie starts with Dylan Branson (Michiel H...
# 17375  Molly Bloom is world-class mogul skier with Ol...
# 17343  Christine "Lady Bird" McPherson is a senior st...
# 17325  The story is told in flashbacks set during a 1...
# 17352  Emily Martin (Noël Wells) returns to her homet...
# ...                                                  ...
# 16203  Sarah (Kate Bosworth) invites her childhood fr...
# 16204  Stone portrays journalist Sofie Talbert, a har...
# 16205  Six weeks after Jason Bourne's (Matt Damon) es...
# 16190  As a storm approaches a southern Louisiana bay...
# 16207  In early 1980s Soviet Russia, young Misha Galk...
#
# [1000 rows x 8 columns]

# %%
from tenacity import retry, wait_random_exponential, stop_after_attempt

@retry(wait=wait_random_exponential(min=1, max=20), stop=stop_after_attempt(6))
def get_embedding(text, model="nomic-ai/nomic-embed-text-v1.5-GGUF"):
    # replace newlines, which can negatively effect performance
    text = text.replace("\n", " ")
    return client.embeddings.create(input = [text], model=model).data[0].embedding

# %%
get_embedding("Your text here")

# %% [markdown]
# ## Establish cache embeddings

# %%
import pickle

embedding_cache_path = "movie_embeddings_cache.pkl"

try:
    embedding_cache = pd.read_pickle(embedding_cache_path)
except FileNotFoundError:
    embedding_cache = {}
with open(embedding_cache_path, "wb") as embedding_cache_file:
    pickle.dump(embedding_cache, embedding_cache_file)
    
def embedding_from_string(
        string,
        model="nomic-ai/nomic-embed-text-v1.5-GGUF",
        embedding_cache=embedding_cache
):
    if (string, model) not in embedding_cache.keys():
        embedding_cache[(string, model)] = get_embedding(string, model)
        print(f"GOT EMBEDDING FROM OPENAI FOR {string[:20]}")
        with open(embedding_cache_path, "wb") as embedding_cache_file:
            pickle.dump(embedding_cache, embedding_cache_file)
    return embedding_cache[(string, model)]

# %%
# generates embeddings
plot_embeddings = [
    embedding_from_string(plot, model="nomic-ai/nomic-embed-text-v1.5") for plot in movie["Plot"].values
]

# %%
plot_embeddings

# %%
data = movie[["Title", "Genre"]].to_dict("records")

# %%
data
